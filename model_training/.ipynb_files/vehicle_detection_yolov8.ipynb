# %%
# !nvidia-smi
# Out:
# Thu Dec  7 02:53:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.68 GB
# CPU                 Intel Xeon 2.00GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.1.0+cu118>=1.8.0
# torchvision         ✅ 0.16.0+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="https://img.freepik.com/free-photo/medium-shot-happy-man-holding-map_23-2148765207.jpg"
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://img.freepik.com/free-photo/medium-shot-happy-man-holding-map_23-2148765207.jpg locally at medium-shot-happy-man-holding-map_23-2148765207.jpg
# image 1/1 /content/medium-shot-happy-man-holding-map_23-2148765207.jpg: 384x640 1 person, 1 dog, 211.3ms
# Speed: 16.3ms preprocess, 211.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='/content/runs/detect/predict2/medium-shot-happy-man-holding-map_23-2148765207.jpg', height=400)
# Out:
# /content

# %%
# %cd {HOME}

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SNlIdda6Dfgb5OXXmkwd")
project = rf.workspace("fyp1").project("final-year-project-8pq8o")
dataset = project.version(1).download("yolov8")
# Out:
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Final-Year-Project-1 in yolov8:: 100%|██████████| 3574/3574 [00:00<00:00, 5289.57it/s]

# %%
# !pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.223
#     Uninstalling ultralytics-8.0.223:
#       Successfully uninstalled ultralytics-8.0.223
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# /content
# ...
# 100% 83.7M/83.7M [00:01<00:00, 80.1MB/s]
# New https://pypi.org/project/ultralytics/8.0.223 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/drive/MyDrive/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/drive/MyDrive/train/results.png', width=600)

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43612776 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/Final-Year-Project-1/valid/labels.cache... 357 images, 0 backgrounds, 0 corrupt: 100% 357/357 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:19<00:00,  1.20it/s]
#                    all        357       1424      0.864      0.883      0.922      0.709
#                 3wheel        357        464      0.913      0.914      0.947      0.729
#                    bus        357        223      0.954       0.93      0.979        0.8
#                    car        357        230      0.819      0.913       0.93      0.704
#                   jeep        357         72      0.777      0.774      0.823      0.673
#                  lorry        357         72      0.826      0.819      0.905      0.701
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/drive/MyDrive/trained_model/train/weights/best.pt conf=0.25 source=/content/Final-Year-Project-1/test
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43612776 parameters, 0 gradients, 164.8 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 445, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 242, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 205, in predict_cli
#     for _ in gen:  # running CLI inference without accumulating any outputs (do not modify)
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/drive/MyDrive/trained_model/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/trained_model/prithvi-side.mp4
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43612776 parameters, 0 gradients, 164.8 GFLOPs
#
# video 1/1 (1/1523) /content/drive/MyDrive/trained_model/prithvi-side.mp4: 384x640 1 3wheel, 10 motorbikes, 87.4ms
# video 1/1 (2/1523) /content/drive/MyDrive/trained_model/prithvi-side.mp4: 384x640 2 3wheels, 1 car, 11 motorbikes, 39.0ms
# video 1/1 (3/1523) /content/drive/MyDrive/trained_model/prithvi-side.mp4: 384x640 1 3wheel, 1 car, 11 motorbikes, 38.9ms
# video 1/1 (4/1523) /content/drive/MyDrive/trained_model/prithvi-side.mp4: 384x640 1 3wheel, 1 car, 12 motorbikes, 32.9ms
# video 1/1 (5/1523) /content/drive/MyDrive/trained_model/prithvi-side.mp4: 384x640 1 3wheel, 1 car, 10 motorbikes, 32.9ms
# video 1/1 (6/1523) /content/drive/MyDrive/trained_model/prithvi-side.mp4: 384x640 1 3wheel, 1 car, 9 motorbikes, 32.9ms
# ...
